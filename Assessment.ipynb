# %% [markdown]
# # 1.Set Up the YOLOv5 Pipeline

# %% [markdown]
# ## Install dependencies

# %%
# !pip install torch torchvision torchaudio
# !pip install ultralytics
# Out:
# Requirement already satisfied: torch in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (2.5.1)
# Requirement already satisfied: torchvision in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (0.20.1)
# Requirement already satisfied: torchaudio in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: ultralytics in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (8.3.49)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (4.66.6)
# Requirement already satisfied: psutil in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (6.1.0)
# Requirement already satisfied: py-cpuinfo in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics) (2.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)

# %% [markdown]
# ## Clone the YOLOv5 repository and set up the environment

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# f:\Assessment\Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO\yolov5
# Cloning into 'yolov5'...
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 6)) (3.9.2)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 8)) (4.10.0.84)
# Requirement already satisfied: pillow>=10.3.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 9)) (11.1.0)
# Requirement already satisfied: psutil in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 10)) (6.1.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 13)) (1.13.1)
# Requirement already satisfied: thop>=0.1.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 15)) (2.5.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 16)) (0.20.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 17)) (4.66.6)
# Requirement already satisfied: ultralytics>=8.2.34 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 18)) (8.3.49)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 27)) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from -r requirements.txt (line 42)) (75.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (6.4.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2024.12.14)
# Requirement already satisfied: filelock in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: networkx in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: colorama in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from tqdm>=4.66.3->-r requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (2.0.10)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3->-r requirements.txt (line 6)) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)

# %% [markdown]
# # 2.Dataset Preparation

# %% [markdown]
# ## Download Dataset
# [about ~50–100 images with bounding box annotations is enough for a
# proof-of-concept. ]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6PdYCi4jBGkqWpGKkaGi")
project = rf.workspace("project-3vvpk").project("dog-and-cat-tmn5b")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# Requirement already satisfied: roboflow in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (1.1.54)
# Requirement already satisfied: certifi in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (2024.12.14)
# Requirement already satisfied: idna==3.7 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (3.9.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (11.1.0)
# Requirement already satisfied: python-dateutil in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (2.9.0)
# Requirement already satisfied: python-dotenv in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (4.66.6)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib->roboflow) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib->roboflow) (4.54.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib->roboflow) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from matplotlib->roboflow) (6.4.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\msi\.conda\envs\fyp_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.20.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in dog-and-cat-2 to yolov5pytorch:: 100%|██████████| 9206/9206 [00:02<00:00, 4133.32it/s]
# Extracting Dataset Version Zip to dog-and-cat-2 in yolov5pytorch:: 100%|██████████| 204/204 [00:00<00:00, 1703.50it/s]

# %% [markdown]
# ## Setup the data.yaml file with the correct dataset path (after the download)

# %% [markdown]
# # 3.Train YOLOv5 on Your Dataset

# %% [markdown]
# ## Train YOLOv5 on the dataset

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data F:/Assessment/Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO/dog-and-cat-2/data.yaml --weights yolov5s.pt
# Out:
# wandb: WARNING  wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# train: weights=yolov5s.pt, cfg=, data=F:/Assessment/Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO/dog-and-cat-2/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-398-g5cdad892 Python-3.9.20 torch-2.5.1+cpu CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# COMET WARNING: Comet credentials have not been set. Comet will default to offline logging. Please set your credentials to enable online logging.
# COMET INFO: Using 'f:\\Assessment\\Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO\\yolov5\\.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/Arial.ttf to C:\Users\MSI\AppData\Roaming\Ultralytics\Arial.ttf...
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
#
#   0%|          | 0.00/755k [00:00<?, ?B/s]
#  17%|█▋        | 128k/755k [00:00<00:00, 744kB/s]
#  51%|█████     | 384k/755k [00:00<00:00, 1.20MB/s]
# 100%|██████████| 755k/755k [00:00<00:00, 2.03MB/s]
# 100%|██████████| 755k/755k [00:00<00:00, 1.71MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
#
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
#   1%|          | 128k/14.1M [00:00<00:21, 685kB/s]
#   3%|▎         | 384k/14.1M [00:00<00:12, 1.11MB/s]
#   5%|▌         | 768k/14.1M [00:00<00:07, 1.95MB/s]
#  11%|█         | 1.50M/14.1M [00:00<00:03, 3.68MB/s]
#  19%|█▉        | 2.75M/14.1M [00:00<00:01, 6.37MB/s]
#  27%|██▋       | 3.88M/14.1M [00:00<00:01, 7.94MB/s]
#  36%|███▋      | 5.12M/14.1M [00:00<00:01, 9.33MB/s]
#  44%|████▍     | 6.25M/14.1M [00:01<00:00, 9.90MB/s]
#  51%|█████▏    | 7.25M/14.1M [00:01<00:00, 9.82MB/s]
#  60%|██████    | 8.50M/14.1M [00:01<00:00, 10.5MB/s]
/it]f:\Assessment\Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#       49/49         0G     0.0236    0.02811   0.006826         78        640:  40%|████      | 2/5 [00:36<00:35, 11.95s/it]
#       49/49         0G     0.0236    0.02811   0.006826         78        640:  60%|██████    | 3/5 [00:36<00:24, 12.18s/it]f:\Assessment\Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#       49/49         0G    0.02874    0.02898   0.007746         80        640:  60%|██████    | 3/5 [00:48<00:24, 12.18s/it]
#       49/49         0G    0.02874    0.02898   0.007746         80        640:  80%|████████  | 4/5 [00:48<00:12, 12.10s/it]f:\Assessment\Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#       49/49         0G    0.02859    0.02728   0.007589         43        640:  80%|████████  | 4/5 [00:57<00:12, 12.10s/it]
#       49/49         0G    0.02859    0.02728   0.007589         43        640: 100%|██████████| 5/5 [00:57<00:00, 11.17s/it]
#       49/49         0G    0.02859    0.02728   0.007589         43        640: 100%|██████████| 5/5 [00:57<00:00, 11.59s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.52s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.52s/it]
#                    all         13         25      0.685      0.833      0.827      0.408
#
# 50 epochs completed in 0.959 hours.
# Optimizer stripped from runs\train\exp\weights\last.pt, 14.4MB
# Optimizer stripped from runs\train\exp\weights\best.pt, 14.4MB
#
# Validating runs\train\exp\weights\best.pt...
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.27s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:02<00:00,  2.27s/it]
#                    all         13         25      0.684      0.749      0.759      0.419
#                    cat         13         15      0.651      0.733      0.776      0.434
#                    dog         13         10      0.717      0.764      0.743      0.403
# Results saved to runs\train\exp
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : exp
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     loss [5]                   : (0.9878031015396118, 3.066883087158203)
# COMET INFO:     metrics/mAP_0.5 [100]      : (0.003347073906099865, 0.8325197160942608)
# COMET INFO:     metrics/mAP_0.5:0.95 [100] : (0.0015720649065808833, 0.41960210774953927)
# COMET INFO:     metrics/precision [100]    : (0.004863053250150025, 0.7301577628593329)
# COMET INFO:     metrics/recall [100]       : (0.03333333333333333, 0.8333333333333334)
# COMET INFO:     train/box_loss [100]       : (0.02858859673142433, 0.1151828020811081)
# COMET INFO:     train/cls_loss [100]       : (0.007588894106447697, 0.02755986526608467)
# COMET INFO:     train/obj_loss [100]       : (0.023743759840726852, 0.04258256405591965)
# COMET INFO:     val/box_loss [100]         : (0.05976291373372078, 0.1309783160686493)
# COMET INFO:     val/cls_loss [100]         : (0.0043891179375350475, 0.02644934132695198)
# COMET INFO:     val/obj_loss [100]         : (0.01696103811264038, 0.02699866145849228)
# COMET INFO:     x/lr0 [100]                : (0.0004960000000000005, 0.0964)
# COMET INFO:     x/lr1 [100]                : (0.0004, 0.006175620000000001)
# COMET INFO:     x/lr2 [100]                : (0.0004, 0.006175620000000001)
# COMET INFO:   Others:
# COMET INFO:     Name                        : exp
# COMET INFO:     comet_log_batch_metrics     : False
# COMET INFO:     comet_log_confusion_matrix  : True
# COMET INFO:     comet_log_per_class_metrics : False
# COMET INFO:     comet_max_image_uploads     : 100
# COMET INFO:     comet_mode                  : online
# COMET INFO:     comet_model_name            : yolov5
# COMET INFO:     hasNestedParams             : True
# COMET INFO:     offline_experiment          : True
# COMET INFO:   Parameters:
# COMET INFO:     anchor_t            : 4.0
# COMET INFO:     artifact_alias      : latest
# COMET INFO:     batch_size          : 16
# COMET INFO:     bbox_interval       : -1
# COMET INFO:     box                 : 0.05
# COMET INFO:     bucket              :
# COMET INFO:     cache               : None
# COMET INFO:     cfg                 :
# COMET INFO:     cls                 : 0.012500000000000002
# COMET INFO:     cls_pw              : 1.0
# COMET INFO:     copy_paste          : 0.0
# COMET INFO:     cos_lr              : False
# COMET INFO:     degrees             : 0.0
# COMET INFO:     device              :
# COMET INFO:     entity              : None
# COMET INFO:     evolve              : None
# COMET INFO:     evolve_population   : data\hyps
# COMET INFO:     exist_ok            : False
# COMET INFO:     fl_gamma            : 0.0
# COMET INFO:     fliplr              : 0.5
# COMET INFO:     flipud              : 0.0
# COMET INFO:     freeze              : [0]
# COMET INFO:     hsv_h               : 0.015
# COMET INFO:     hsv_s               : 0.7
# COMET INFO:     hsv_v               : 0.4
# COMET INFO:     hyp|anchor_t        : 4.0
# COMET INFO:     hyp|box             : 0.05
# COMET INFO:     hyp|cls             : 0.5
# COMET INFO:     hyp|cls_pw          : 1.0
# COMET INFO:     hyp|copy_paste      : 0.0
# COMET INFO:     hyp|degrees         : 0.0
# COMET INFO:     hyp|fl_gamma        : 0.0
# COMET INFO:     hyp|fliplr          : 0.5
# COMET INFO:     hyp|flipud          : 0.0
# COMET INFO:     hyp|hsv_h           : 0.015
# COMET INFO:     hyp|hsv_s           : 0.7
# COMET INFO:     hyp|hsv_v           : 0.4
# COMET INFO:     hyp|iou_t           : 0.2
# COMET INFO:     hyp|lr0             : 0.01
# COMET INFO:     hyp|lrf             : 0.01
# COMET INFO:     hyp|mixup           : 0.0
# COMET INFO:     hyp|momentum        : 0.937
# COMET INFO:     hyp|mosaic          : 1.0
# COMET INFO:     hyp|obj             : 1.0
# COMET INFO:     hyp|obj_pw          : 1.0
# COMET INFO:     hyp|perspective     : 0.0
# COMET INFO:     hyp|scale           : 0.5
# COMET INFO:     hyp|shear           : 0.0
# COMET INFO:     hyp|translate       : 0.1
# COMET INFO:     hyp|warmup_bias_lr  : 0.1
# COMET INFO:     hyp|warmup_epochs   : 3.0
# COMET INFO:     hyp|warmup_momentum : 0.8
# COMET INFO:     hyp|weight_decay    : 0.0005
# COMET INFO:     image_weights       : False
# COMET INFO:     imgsz               : 640
# COMET INFO:     iou_t               : 0.2
# COMET INFO:     label_smoothing     : 0.0
# COMET INFO:     local_rank          : -1
# COMET INFO:     lr0                 : 0.01
# COMET INFO:     lrf                 : 0.01
# COMET INFO:     mixup               : 0.0
# COMET INFO:     momentum            : 0.937
# COMET INFO:     mosaic              : 1.0
# COMET INFO:     multi_scale         : False
# COMET INFO:     name                : exp
# COMET INFO:     ndjson_console      : False
# COMET INFO:     ndjson_file         : False
# COMET INFO:     noautoanchor        : False
# COMET INFO:     noplots             : False
# COMET INFO:     nosave              : False
# COMET INFO:     noval               : False
# COMET INFO:     obj                 : 1.0
# COMET INFO:     obj_pw              : 1.0
# COMET INFO:     optimizer           : SGD
# COMET INFO:     patience            : 100
# COMET INFO:     perspective         : 0.0
# COMET INFO:     project             : runs\train
# COMET INFO:     quad                : False
# COMET INFO:     rect                : False
# COMET INFO:     resume              : False
# COMET INFO:     resume_evolve       : None
# COMET INFO:     save_dir            : runs\train\exp
# COMET INFO:     save_period         : -1
# COMET INFO:     scale               : 0.5
# COMET INFO:     seed                : 0
# COMET INFO:     shear               : 0.0
# COMET INFO:     single_cls          : False
# COMET INFO:     sync_bn             : False
# COMET INFO:     translate           : 0.1
# COMET INFO:     upload_dataset      : False
# COMET INFO:     val_conf_threshold  : 0.001
# COMET INFO:     val_iou_threshold   : 0.6
# COMET INFO:     warmup_bias_lr      : 0.1
# COMET INFO:     warmup_epochs       : 3.0
# COMET INFO:     warmup_momentum     : 0.8
# COMET INFO:     weight_decay        : 0.0005
# COMET INFO:     workers             : 8
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 13 (1.18 MB)
# COMET INFO:     confusion-matrix    : 1
# COMET INFO:     environment details : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     images              : 6
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:
# COMET INFO: Still saving offline stats to messages file before program termination (may take up to 120 seconds)
# COMET INFO: Begin archiving the offline data.
# COMET INFO: To upload this offline experiment, run:
#     comet upload f:\Assessment\Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO\yolov5\.cometml-runs\d7dfc8727c8f44ccade77eead024d2ab.zip

# %% [markdown]
# # 4. Define a Custom Bounding Box Similarity Metric

# %% [markdown]
# In this step, we define a custom similarity metric for bounding boxes, focusing on the Intersection over Union (IoU) as a standard measure for evaluating the overlap between two bounding boxes.
#
# ### What is IoU (Intersection over Union)?
#
# IoU is a widely used metric for evaluating the similarity between two bounding boxes. It is defined as the ratio of the area of overlap between two bounding boxes to the area of their union.
#
# ### Formula:
#
# The formula for IoU is:
#
# $$
# IoU = \frac{\text{Area of Overlap}}{\text{Area of Union}}
# $$
#
# Where:
#
# - **Area of Overlap**: The area where the two bounding boxes overlap.
# - **Area of Union**: The total area covered by both bounding boxes, including their overlap.
#
# ### Steps to Calculate IoU:
#
# 1. **Calculate the Area of Overlap**:
#    - Find the intersection of the two bounding boxes.
#
# 2. **Calculate the Area of Union**:
#    - Find the total area covered by both bounding boxes combined.
#
# 3. **Compute IoU**:
#    - Divide the area of overlap by the area of union to get the IoU score.

# %%
import numpy as np
import torch

def custom_bbox_similarity(box1, box2):
    """
    Compute a custom bounding box similarity score.
    Inputs:
        - box1, box2: Bounding boxes in [x1, y1, x2, y2] format
    Returns:
        - similarity score (0 to 1)
    """
    # Compute IoU
    def compute_iou(box1, box2):
        x1 = max(box1[0], box2[0])
        y1 = max(box1[1], box2[1])
        x2 = min(box1[2], box2[2])
        y2 = min(box1[3], box2[3])

        intersection = max(0, x2 - x1) * max(0, y2 - y1)
        area1 = (box1[2] - box1[0]) * (box1[3] - box1[1])
        area2 = (box2[2] - box2[0]) * (box2[3] - box2[1])
        union = area1 + area2 - intersection

        return intersection / union if union > 0 else 0

    iou = compute_iou(box1, box2)

    # Compute center distance penalty
    center1 = [(box1[0] + box1[2]) / 2, (box1[1] + box1[3]) / 2]
    center2 = [(box2[0] + box2[2]) / 2, (box2[1] + box2[3]) / 2]
    center_dist = np.linalg.norm(np.array(center1) - np.array(center2))
    center_penalty = np.exp(-center_dist / 50)  # Normalize by 50 pixels

    # Compute aspect ratio similarity
    def aspect_ratio(box):
        return (box[2] - box[0]) / (box[3] - box[1]) if (box[3] - box[1]) > 0 else 1

    aspect_ratio_similarity = 1 - abs(aspect_ratio(box1) - aspect_ratio(box2)) / max(aspect_ratio(box1), aspect_ratio(box2))

    # Weighted combination
    similarity_score = (iou + center_penalty + aspect_ratio_similarity) / 3
    return similarity_score

# %% [markdown]
# # 5. Integrate Metric into Training or Evaluation

# %%
# !python val.py --data F:/Assessment/Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO/dog-and-cat-2/data.yaml --weights runs/train/exp/weights/best.pt
# Out:
# Custom Metric (Avg Similarity Score) for batch 0: 0.2995
# Custom Metric (Avg Similarity Score) for batch 1: 0.4495
# Custom Metric (Avg Similarity Score) for batch 2: 0.2714
# Custom Metric (Avg Similarity Score) for batch 3: 0.2636
# Custom Metric (Avg Similarity Score) for batch 4: 0.2649
# Custom Metric (Avg Similarity Score) for batch 5: 0.2936
# Custom Metric (Avg Similarity Score) for batch 6: 0.3767
# Custom Metric (Avg Similarity Score) for batch 7: 0.3059
# Custom Metric (Avg Similarity Score) for batch 8: 0.2962
# Custom Metric (Avg Similarity Score) for batch 9: 0.3266
# Custom Metric (Avg Similarity Score) for batch 10: 0.4677
# Custom Metric (Avg Similarity Score) for batch 11: 0.3493
# Custom Metric (Avg Similarity Score) for batch 12: 0.3336
# val: data=F:/Assessment/Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO/dog-and-cat-2/data.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-398-g5cdad892 Python-3.9.20 torch-2.5.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#
# val: Scanning F:\Assessment\Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO\dog-and-cat-2\valid\labels.cache... 13 images, 0 backgrounds, 0 corrupt: 100%|██████████| 13/13 [00:00<?, ?it/s]
# val: Scanning F:\Assessment\Custom_Object_Detection_and_Novel_Bounding_Box_Metric_with_YOLO\dog-and-cat-2\valid\labels.cache... 13 images, 0 backgrounds, 0 corrupt: 100%|██████████| 13/13 [00:00<?, ?it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:16<00:00, 16.27s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 1/1 [00:16<00:00, 16.27s/it]
#                    all         13          0          0          0          0          0
# WARNING  no labels found in val set, can not compute metrics without labels
# Speed: 1.5ms pre-process, 120.0ms inference, 1.4ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs\val\exp4
